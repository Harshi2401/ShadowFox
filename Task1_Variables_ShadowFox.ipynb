# %%
pi=22/7
print("value of pi:",pi)
type(pi)
# Out:
# value of pi: 3.142857142857143
# float

# %%
for=4
# Out:
#   File "<ipython-input-5-a1eeb42932d4>", line 1
#     for=4
#        ^
# SyntaxError: invalid syntax

# %%
for_var=4
print("Value of for_var:",for_var)
# Out:
# Value of for_var: 4

# %%
#Declare variabls
p=100#principal
R=5#Rate of Interest
T=3#Time in years
#Calculate Simple Interest
# Changed P to p to match the declared variable
SI = (p * T * R) / 100
print("simple Interest is:",SI)
# Out:
# simple Interest is: 15.0
